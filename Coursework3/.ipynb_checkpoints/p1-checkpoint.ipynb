# %%
import datetime as dt
import pandas_datareader as pdr
import matplotlib.pyplot as plt
from matplotlib import style

start = dt.datetime(2010,1,1)
end = dt.datetime.now()

df = pdr.DataReader(["DJIA","SP500"],"fred",start,end)

print("\nPrint number of records: ")

print(df.columns)

print("\nPrind data frame: ")
print(df)

print("\nPrint first five lines: ")
print(df.head())
print("\nPrint last five lines: ")
print(df.tail())
print("\nPrint first 2 lines: ")
print(df.head(2))
print("\nPrint last 2 lines: ")
print(df.tail(2))

style.use('ggplot')

df['DJIA'].plot()
df['SP500'].plot()
plt.legend()
plt.show()
# Out:
# Print number of records:
# Index(['DJIA', 'SP500'], dtype='object')
#
# Prind data frame:
#                 DJIA    SP500
# DATE
# 2013-10-28  15568.93  1762.11
# 2013-10-29  15680.35  1771.95
# 2013-10-30  15618.76  1763.31
# 2013-10-31  15545.75  1756.54
# 2013-11-01  15615.55  1761.64
# ...              ...      ...
# 2023-10-19  33414.17  4278.00
# 2023-10-20  33127.28  4224.16
# 2023-10-23  32936.41  4217.04
# 2023-10-24  33141.38  4247.68
# 2023-10-25  33035.93  4186.77
#
# [2608 rows x 2 columns]
#
# Print first five lines:
#                 DJIA    SP500
# DATE
# 2013-10-28  15568.93  1762.11
# 2013-10-29  15680.35  1771.95
# 2013-10-30  15618.76  1763.31
# 2013-10-31  15545.75  1756.54
# 2013-11-01  15615.55  1761.64
#
# Print last five lines:
#                 DJIA    SP500
# DATE
# 2023-10-19  33414.17  4278.00
# 2023-10-20  33127.28  4224.16
# 2023-10-23  32936.41  4217.04
# 2023-10-24  33141.38  4247.68
# 2023-10-25  33035.93  4186.77
#
# Print first 2 lines:
#                 DJIA    SP500
# DATE
# 2013-10-28  15568.93  1762.11
# 2013-10-29  15680.35  1771.95
#
# Print last 2 lines:
#                 DJIA    SP500
# DATE
# 2023-10-24  33141.38  4247.68
# 2023-10-25  33035.93  4186.77
# C:\Users\khali\anaconda3\Lib\site-packages\matplotlib\axis.py:1732: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   ret = self.converter.convert(x, self.units, self)
# C:\Users\khali\anaconda3\Lib\site-packages\matplotlib\axis.py:1732: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   ret = self.converter.convert(x, self.units, self)
# C:\Users\khali\anaconda3\Lib\site-packages\matplotlib\axis.py:1484: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   return self.major.locator()
# C:\Users\khali\anaconda3\Lib\site-packages\matplotlib\axis.py:1484: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   return self.major.locator()
# C:\Users\khali\anaconda3\Lib\site-packages\matplotlib\ticker.py:218: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   return [self(value, i) for i, value in enumerate(values)]
# C:\Users\khali\anaconda3\Lib\site-packages\matplotlib\axis.py:1732: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   ret = self.converter.convert(x, self.units, self)
# C:\Users\khali\anaconda3\Lib\site-packages\matplotlib\axis.py:1484: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   return self.major.locator()
# C:\Users\khali\anaconda3\Lib\site-packages\matplotlib\axis.py:1484: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   return self.major.locator()
# C:\Users\khali\anaconda3\Lib\site-packages\matplotlib\ticker.py:218: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   return [self(value, i) for i, value in enumerate(values)]
